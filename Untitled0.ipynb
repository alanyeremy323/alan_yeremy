# %%
radio = float ( input("ingrese el radio= "))
circunferencia= 2 * 3.14159265359 * radio 
print( f"La circunferencia es= {circunferencia}")
# Out:
# ingrese el radio= 3
# La circunferencia es= 18.849555921540002
